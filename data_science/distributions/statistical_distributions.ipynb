# %% [markdown]
# # Statistical distribitions

# %% [markdown]
# ## Confiurations

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm

# %% [markdown]
# # Creating Random Normal data

# %%
n = 200
df = pd.DataFrame(dict(
  height=abs(np.random.normal(1.75,.1,size=n)),
  weight=abs(np.random.normal(150,10,size=n))
))
df['height'].hist(bins=10)
# Out:
# <Axes: >

# %%
df['weight'].hist(bins=10)
# Out:
# <Axes: >

# %%
plt.style.use("ggplot")
fig, ax = plt.subplots()
ax.plot(df["height"])
ax.plot(df["weight"], color="b")
plt.show()
plt.clf()

# %%
# Plotting the histogram using value counts instead of density
plt.figure(figsize=(10, 6))
bin_count = 25
sns.histplot(df['weight'], kde=False, bins=bin_count, label='Histogram', color='skyblue', stat="count")

# Adjusting the normal curve for counts
bin_width = (xmax - xmin) / bin_count
p_counts = norm.pdf(x, df['weight'].mean(), df['weight'].std()) * bin_width * n
plt.plot(x, p_counts, 'k', linewidth=2, label='Normal Distribution')

title = "Fit results: mean = %.2f,  std = %.2f" % (df['weight'].mean(), df['weight'].std())
plt.title(title)
plt.legend()
plt.show()
